# %%
import os
import numpy as np
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras import optimizers
from keras import applications
from keras.models import Model
 
 
 
train_data_dir = 'C:/Users/i7/Desktop/Trivial Solution/data_'
 
 
 
datagen = ImageDataGenerator(rescale=1./255)
batch_size = 256
img_width, img_height = 150, 150
 
# automagically retrieve images and their classes for train and validation sets
train_generator = datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_width, img_height))
 
 
 
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(img_height,img_width, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
 
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(10))
model.add(Activation('softmax'))
 
 
 
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
train_samples = 514
 
epochs = 100
model.fit_generator(
        train_generator,
        steps_per_epoch=train_samples//batch_size, epochs=epochs)
# Out:
# Found 514 images belonging to 10 classes.
# Epoch 1/100
# 2/2 [==============================] - 4s 2s/step - loss: 4.8110 - acc: 0.1562
# Epoch 2/100
# 2/2 [==============================] - 3s 1s/step - loss: 3.8474 - acc: 0.1250
# Epoch 3/100
# 2/2 [==============================] - 3s 1s/step - loss: 2.5701 - acc: 0.1094
# Epoch 4/100
# 2/2 [==============================] - 2s 1s/step - loss: 2.3187 - acc: 0.1719
# Epoch 5/100
# 2/2 [==============================] - 1s 693ms/step - loss: 2.3126 - acc: 0.0809
# Epoch 6/100
# 2/2 [==============================] - 2s 1s/step - loss: 2.2987 - acc: 0.1250
# Epoch 7/100
# 2/2 [==============================] - 2s 1s/step - loss: 2.2945 - acc: 0.1406
# Epoch 8/100
# 2/2 [==============================] - 3s 1s/step - loss: 2.2957 - acc: 0.1250
# Epoch 9/100
# 2/2 [==============================] - 3s 1s/step - loss: 2.2888 - acc: 0.1719
# Epoch 10/100
# 2/2 [==============================] - 3s 1s/step - loss: 2.2398 - acc: 0.1719
# ...

# %%
 
 
 
 
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.inception_v3 import preprocess_input
import glob
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.inception_v3 import preprocess_input
import cv2
import numpy as np
from matplotlib import pyplot as plt

for im in glob.glob("C:/Users/i7/Desktop/t/*.jpg"):
    img = load_img(im, target_size=(150,150))
 
    x = img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    preds = model.predict_classes(x)
    prob = model.predict_proba(x)
    print(preds)
    plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
    plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
    plt.show()
# Out:
# [6]
# [5]
# [9]
# [8]
# [2]
# [3]
# [3]
# [4]
# [5]
# [1]
# [7]

# %%
import glob
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.inception_v3 import preprocess_input

for im in glob.glob("C:/Users/i7/Desktop/Trivial Solution/data_/t/*.jpg"):
    img = load_img(im, target_size=(150,150))
 
    x = img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    preds = model.predict_classes(x)
    prob = model.predict_proba(x)
    print(preds)
# Out:
# [6]
# [5]
# [9]
# [8]
# [2]
# [5]
# [1]

# %%
top_model_weights_path = 'weights.h5'

# %%
model.load_weights("weights.h5")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-22-49c7c8ab36ca> in <module>()
# ----> 1 model.load_weights("weights.h5")
#
# C:\Users\i7\Anaconda3\lib\site-packages\keras\models.py in load_weights(self, filepath, by_name, skip_mismatch, reshape)
#     752         if h5py is None:
#     753             raise ImportError('`load_weights` requires h5py.')
# --> 754         with h5py.File(filepath, mode='r') as f:
#     755             if 'layer_names' not in f.attrs and 'model_weights' in f:
#     756                 f = f['model_weights']
#
# C:\Users\i7\Anaconda3\lib\site-packages\h5py\_hl\files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     310             with phil:
#     311                 fapl = make_fapl(driver, libver, **kwds)
# --> 312                 fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
# ...
